# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/Cleaned-Data.parquet
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__results__.html
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__notebook__.ipynb
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/FilterSchema.pickle
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__output__.json
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/custom.css
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__results___files/__results___72_1.png
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__results___files/__results___26_1.png
# /kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/__results___files/__results___53_0.png
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pickle

FilterSchema = pickle.load(open('/kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/FilterSchema.pickle','rb'))

import json

print(json.dumps(FilterSchema,indent=1))
# Out:
# {
#  "Temperature(F)": [
#   -60,
#   130
#  ],
#  "Humidity(%)": [
#   1,
#   100
#  ],
#  "Pressure(in)": [
#   20,
#   32.5
#  ],
#  "Visibility(mi)": [
#   0,
#   30
#  ],
#  "Wind_Speed(mph)": [
#   0,
#   150
#  ],
#  "DROPPED": [
#   "Wind_Chill",
#   "Visibility(mi)"
#  ],
#  "MEDIAN IMPUTE": [
#   "Wind_Direction",
#   "Temperature(F)",
#   "Humidity(%)",
#   "Pressure(in)",
#   "Visibility(mi)",
#   "Wind_Speed(mph)"
#  ],
#  "ARBITRARY IMPUTE : MISSING": null,
#  "ARBITRARY IMPUTE : 0": [
#   "Precipitation(in)"
#  ],
#  "MISSING INDICATOR": [
#   "Precipitation(in)"
#  ]
# }

# %%
df = pd.read_parquet('/kaggle/input/notebooks/animeguylrn/us-accidents-feature-enginnering-experiments/Cleaned-Data.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7715519 entries, 0 to 7728393
# Data columns (total 45 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Source                 uint8
#  1   Severity               uint8
#  2   Start_Lat              float64
#  3   Start_Lng              float64
#  4   End_Lat                float64
#  5   End_Lng                float64
#  6   Distance(mi)           float64
#  7   Street                 object
#  8   City                   object
#  9   County                 object
#  10  State                  object
#  11  Timezone               object
#  12  Temperature(F)         float64
#  13  Wind_Chill(F)          float64
#  14  Humidity(%)            float64
#  15  Pressure(in)           float64
#  16  Visibility(mi)         float64
#  17  Wind_Direction         object
#  18  Wind_Speed(mph)        float64
#  19  Precipitation(in)      float64
#  20  Weather_Condition      object
# ...

# %%
cat_cols = ['Street','City','County','State','Timezone','Wind_Direction','Weather_Condition','Sunrise_Sunset','Civil_Twilight','Nautical_Twilight','Astronomical_Twilight']
for col in cat_cols:
    df[col] = df[col].astype(pd.Categorical)
